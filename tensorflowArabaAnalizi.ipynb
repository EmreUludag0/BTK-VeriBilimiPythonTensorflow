# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_excel("merc.xlsx")
dataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull()
# Out:
#         year  price  transmission  mileage    tax    mpg  engineSize
# 0      False  False         False    False  False  False       False
# 1      False  False         False    False  False  False       False
# 2      False  False         False    False  False  False       False
# 3      False  False         False    False  False  False       False
# 4      False  False         False    False  False  False       False
# ...      ...    ...           ...      ...    ...    ...         ...
# 13114  False  False         False    False  False  False       False
# 13115  False  False         False    False  False  False       False
# 13116  False  False         False    False  False  False       False
# 13117  False  False         False    False  False  False       False
# 13118  False  False         False    False  False  False       False
#
# [13119 rows x 7 columns]

# %%
dataFrame.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["price"])
# Out:
# C:\Users\emreu\AppData\Local\Temp\ipykernel_8204\686912093.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(dataFrame["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sbn.distplot([dataFrame["year"]])
# Out:
# C:\Users\emreu\AppData\Local\Temp\ipykernel_8204\3340042814.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot([dataFrame["year"]])
# <Axes: ylabel='Density'>

# %%
#dataFrame.corr()["transmission"].sort_values()

# %%
sbn.scatterplot(x="mileage",y="price",data=dataFrame)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending=False).head(20)#False, fiyat tablosunun azalan sıralaması ile gösterir.
dataFrame.sort_values("price",ascending=True).head(20)
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(dataFrame)
# Out:
# 13119

# %%
#yDDdF = yüzdeDoksanDokuzDf
yDDdF = dataFrame.sort_values("price",ascending=False).iloc[131:] #indexe göre sıralar.

# %%
yDDdF.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize=(7,5))
sbn.distplot(yDDdF["price"]) #price dağılımını verir.
# Out:
# C:\Users\emreu\AppData\Local\Temp\ipykernel_8204\3300398871.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(yDDdF["price"]) #price dağılımını verir.
# <Axes: xlabel='price', ylabel='Density'>

# %%
yDDdF.groupby("year").mean("price")
# Out:
#              price       mileage         tax        mpg  engineSize
# year
# 1970  24999.000000  14000.000000  305.000000  39.200000    0.000000
# 1997   9995.000000  76000.000000  255.000000  28.200000    3.200000
# 1998   8605.000000  76347.750000  262.500000  28.925000    3.450000
# 1999   5995.000000  34000.000000  145.000000  24.600000    3.200000
# 2000   5743.333333  89648.666667  268.333333  26.333333    3.200000
# 2001   4957.900000  72955.100000  347.500000  28.140000    2.870000
# 2002   5820.444444  57391.111111  350.555556  27.877778    3.522222
# 2003   4878.000000  88777.714286  300.000000  29.485714    3.028571
# 2004   4727.615385  94363.461538  312.307692  31.838462    2.530769
# 2005   4426.111111  80651.333333  303.333333  35.344444    2.377778
# 2006   4036.875000  94347.375000  412.500000  34.375000    2.812500
# 2007   5136.045455  80309.000000  351.136364  36.363636    2.263636
# 2008   6967.437500  81442.437500  342.812500  34.343750    2.662500
# ...

# %%
dataFrame = dataFrame.drop("transmission", axis=1)

# %%
y = dataFrame["price"].values
x = dataFrame.drop("price", axis=1).values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_train)
# Out:
# 9183

# %%
len(x_test)
# Out:
# 3936

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (9183, 5)

# %%
model = Sequential()

model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam", loss="mse")
# Out:
# WARNING:tensorflow:From c:\Users\emreu\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(x= x_train, y= y_train,validation_data=(x_test,y_test),batch_size=250, epochs=300)
# Out:
# Epoch 1/300
# WARNING:tensorflow:From c:\Users\emreu\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 37/37 [==============================] - 1s 5ms/step - loss: 741845504.0000 - val_loss: 769874560.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 2ms/step - loss: 741833280.0000 - val_loss: 769857024.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 2ms/step - loss: 741801856.0000 - val_loss: 769800192.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 2ms/step - loss: 741696128.0000 - val_loss: 769621440.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 2ms/step - loss: 741398080.0000 - val_loss: 769144960.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 2ms/step - loss: 740653760.0000 - val_loss: 768016000.0000
# Epoch 7/300
# ...

# %%
kayipVerisi = pd.DataFrame(model.history.history)
kayipVerisi.head()
# Out:
#           loss     val_loss
# 0  741845504.0  769874560.0
# 1  741833280.0  769857024.0
# 2  741801856.0  769800192.0
# 3  741696128.0  769621440.0
# 4  741398080.0  769144960.0

# %%
kayipVerisi.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
tahminDizisi = model.predict(x_test)
tahminDizisi
# Out:
# 123/123 [==============================] - 0s 697us/step
# array([[38300.793],
#        [30006.848],
#        [41081.37 ],
#        ...,
#        [23817.133],
#        [19221.15 ],
#        [22038.29 ]], dtype=float32)

# %%
mean_absolute_error(y_test, tahminDizisi)
# Out:
# 3804.597933389307

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.scatter(y_test, tahminDizisi)
plt.plot(y_test,y_test,"g--")

# %%
dataFrame.iloc[2]
# Out:
# year           2016.0
# price         49948.0
# mileage        6200.0
# tax             555.0
# mpg              28.0
# engineSize        5.5
# Name: 2, dtype: float64

# %%
yeniArabaSeries = dataFrame.drop("price",axis=1).iloc[2]

# %%
yeniArabaSeries
# Out:
# year          2016.0
# mileage       6200.0
# tax            555.0
# mpg             28.0
# engineSize       5.5
# Name: 2, dtype: float64

# %%
yeniArabaSeries = scaler.transform(yeniArabaSeries.values.reshape(-1,5))

# %%
model.predict(yeniArabaSeries)
# Out:
# 1/1 [==============================] - 0s 63ms/step
# array([[62095.75]], dtype=float32)
