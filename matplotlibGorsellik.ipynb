# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1 = np.linspace(0,10,20)
numpyDizisi2 = numpyDizisi1 ** 2

# %%
(benimfigur, benimEksen) = pyt.subplots()
benimEksen.plot(numpyDizisi1, numpyDizisi2, "r.-")
benimEksen.plot(numpyDizisi2,numpyDizisi1, "#7eafac", alpha = 0.3) #alpha, çizgi rengini soyutlamaya yarar.

# %%
(yeniFigur, yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 2, color = "blue", linewidth= 8.0) #linewidth, çizgi kalınlığını ayarlamaya yarıyor.
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 3, color = "yellow")

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4, color = "#7eafac", linestyle = "-.")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 5, color = "#FF007F", linestyle = ":")

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 6, color = "#000000", linestyle = "--", marker = "o", markerfacecolor = "red")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 7, color = "#000000", linestyle = "--", marker = "o", markersize = 9)

# %% [markdown]
# SCATTER

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# HISTOGRAM

# %%
yeniDizi = np.random.randint(0,100,50)

# %%
plt.hist(yeniDizi)
# Out:
# (array([4., 5., 3., 6., 5., 2., 6., 4., 7., 8.]),
#  array([ 4. , 13.5, 23. , 32.5, 42. , 51.5, 61. , 70.5, 80. , 89.5, 99. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# BOXPLOT

# %%
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14c598dd4b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14c598dd9f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14c598dd210>],
#  'medians': [<matplotlib.lines.Line2D at 0x14c598ddf30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14c598de1d0>],
#  'means': []}

# %% [markdown]
# Matplotlib ders sonu notu:
# Matplotlib web sayfasında örnekler var. lazım olunduğunda bakılması gerekebilir.
